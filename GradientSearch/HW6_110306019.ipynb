# %% [markdown]
# #### A simple gradient search for IntroML@cs.nccu.edu.tw
# #### prepared by Chao-Lin Liu

# %% [markdown]
# ##### $f_1(x) = 2x^2-7x+2$
# ##### $f_2(x) = x^4-8x^2+3x$
# ##### $f_3(x) = x^6-3x^4-8x^2+2x$
# ##### $f_4(x) = x^3-14x^2+56x-56$
# ##### $f_5(x)=x^5-10x^4+53x^3-160x^2+224x-100$
# ##### visualization: https://www.desmos.com/calculator/rgfy6fjksb

# %% [markdown]
# ### 任務
# #### 利用以下程式，找到上述五個函數不是正負無限大($\pm\infty$)的 global/local maximum 和 global/local minimum
# ##### 回答方式，說明你把 guess、step_size 設定多少的時候，會找到 $x$ 使函數 $f_i(x),\ i=1,2,3,4,5$ 有局部極值，此時 $x$ 和 $f_i(x)$ 分別為多少？
# ##### 附加問題一：如果限定極值的精確度必須至下數點以下某一個位數，例如小數點以下第三位的話，對於你的答案會有何影響？
# ##### 附加問題二：你的答案是否是唯一選擇？有沒有其他可能的設定也能找到答案？
# ##### 附加問題三：如果函數有兩個或者兩個以上不同的 local minimum 的話，我們如何找到比較小的 local minimum?
# ##### 附加問題四：如果 guess=$\alpha$、step_size=$\beta$ 可以讓自己找到精確到小數點以下第三位的答案，那減小 step_size 的影響為何？增大 step_size 的影響為何？

# %%
func_1 = lambda x: 2*x*x-7*x+2
func_2 = lambda x: x*x*x*x-8*x*x+3*x
func_3 = lambda x: x**6 - 3*x**4 - 8*x**2 +2*x
func_4 = lambda x: x**3 - 14*x**2 + 56*x - 56
func_5 = lambda x: x**5 - 10*x**4 + 53*x**3 - 160*x**2 + 224*x - 100

func = func_1
print(func(3))
# Out:
# -1

# %%
# your patience
# stop this program, when we have tried max_iter steps
class ExtremumFinder:
  def __init__(self, init_guess, step_size, func):
      # This is your first guess
      self.init_guess = init_guess

      # kicking off the search
      # 選定左右鄰居的間距
      self.step_size = step_size

      self.max_iter = 10000
      self.func = func

  def set_hp(self, guess, step_size, func):
    self.init_guess = guess
    self.step_size = step_size
    self.func = func

  def find_nearest_minimum(self):
    # starting from zeroth iteration
    iter = 0
    guess = self.init_guess

    while iter < self.max_iter:
        prev = guess  # save the previous guess
        guess1 = prev + self.step_size  # move to the next guess
        guess2 = prev - self.step_size
        if self.func(guess1) < self.func(guess2):
            attempt = guess1
        else:
            attempt = guess2
        if self.func(prev) > self.func(attempt):
            guess = attempt
        else:
            break
        iter = iter+1
        print(f"Iteration:  {iter} \n  current guess is: {guess} \n  f(guess) is: {self.func(guess)} \n")


    print(f"I set the initial guess to '{self.init_guess}' and the step size to '{self.step_size}'.")
    print(f"The minimum is {self.func(guess)} when the search stops at x = {guess}. ")
    print("="*40)

    return self.func(guess)

  def find_nearest_maximum(self):
    # starting from zeroth iteration
    iter = 0
    guess = self.init_guess

    while iter < self.max_iter:
        prev = guess  # save the previous guess
        guess1 = prev + self.step_size  # move to the next guess
        guess2 = prev - self.step_size
        if self.func(guess1) > self.func(guess2):
            attempt = guess1
        else:
            attempt = guess2
        if self.func(prev) < self.func(attempt):
            guess = attempt
        else:
            break
        iter = iter+1
        print(f"Iteration:  {iter} \n  current guess is: {guess} \n  f(guess) is: {self.func(guess)} \n")

    print(f"I set the initial guess to '{self.init_guess}' and the step size to '{self.step_size}'.")
    print(f"The maximum is {self.func(guess)} when the search stops at x = {guess}. ")
    print("="*40)

    return self.func(guess)

# %%
finder = ExtremumFinder(-4, 1, func_1)

# %%
finder.find_nearest_minimum()
# Out:
# Iteration:  1
#   current guess is: -3
#   f(guess) is: 41
#
# Iteration:  2
#   current guess is: -2
#   f(guess) is: 24
#
# Iteration:  3
#   current guess is: -1
#   f(guess) is: 11
#
# Iteration:  4
#   current guess is: 0
#   f(guess) is: 2
#
# Iteration:  5
#   current guess is: 1
#   f(guess) is: -3
#
# Iteration:  6
#   current guess is: 2
#   f(guess) is: -4
#
# I set the initial guess to '-4' and the step size to '1'.
# The minimum is -4 when the search stops at x = 2.
# ========================================
# -4

# %% [markdown]
# # 問題

# %%
print("""
  以下問題我都先以step_size = 1(整數)的情形討論
  後面附加問題再討論小數的step_size結果為何
""")
# Out:
#   以下問題我都先以step_size = 1(整數)的情形討論
#   後面附加問題再討論小數的step_size結果為何

# %%
finder = ExtremumFinder(-4, 1, func_1)

# %%
# 問題一
# Use desmos to simply approximate the point

# fun1
print("<<Funcion1>>\n")

print("<Local Minimum>")
finder.find_nearest_minimum()

print("<Global Minimum>")
finder.find_nearest_minimum()

print("<Local Maximum>")
print("超過迴圈上線")
print("="*40)

print("<Global Maximum>")
print("超過迴圈上線")
print("="*40)
# Out:
# <<Funcion1>>
#
# <Local Minimum>
# Iteration:  1
#   current guess is: -3
#   f(guess) is: 41
#
# Iteration:  2
#   current guess is: -2
#   f(guess) is: 24
#
# Iteration:  3
#   current guess is: -1
#   f(guess) is: 11
#
# Iteration:  4
#   current guess is: 0
#   f(guess) is: 2
#
# Iteration:  5
#   current guess is: 1
#   f(guess) is: -3
#
# Iteration:  6
#   current guess is: 2
#   f(guess) is: -4
#
# I set the initial guess to '-4' and the step size to '1'.
# The minimum is -4 when the search stops at x = 2.
# ========================================
# <Global Minimum>
# Iteration:  1
#   current guess is: -3
#   f(guess) is: 41
#
# Iteration:  2
#   current guess is: -2
#   f(guess) is: 24
#
# Iteration:  3
#   current guess is: -1
#   f(guess) is: 11
#
# Iteration:  4
#   current guess is: 0
#   f(guess) is: 2
#
# Iteration:  5
#   current guess is: 1
#   f(guess) is: -3
#
# Iteration:  6
#   current guess is: 2
#   f(guess) is: -4
#
# I set the initial guess to '-4' and the step size to '1'.
# The minimum is -4 when the search stops at x = 2.
# ========================================
# <Local Maximum>
# 超過迴圈上線
# ========================================
# <Global Maximum>
# 超過迴圈上線
# ========================================

# %%
# func2
print("<<Funcion2>>\n")

print("<Local Minimum>")
finder.set_hp(-4, 1, func_2)
finder.find_nearest_minimum()

print("<Global Minimum>")
finder.set_hp(-4, 1, func_2)
min_1 = finder.find_nearest_minimum()

finder.set_hp(3, 1, func_2)
min_2 = finder.find_nearest_minimum()

global_min = min([min_1, min_2])
print(f"min([{min_1}, {min_2}]) = {global_min} \n Therefore, the global miminum is {global_min}. ")
print("="*40)

print("<Local Maximum>")
finder.set_hp(1, 1, func_2)
finder.find_nearest_maximum()

print("<Global Maximum>")
finder.set_hp(1, 1, func_2)
finder.find_nearest_maximum()
# Out:
# <<Funcion2>>
#
# <Local Minimum>
# Iteration:  1
#   current guess is: -3
#   f(guess) is: 0
#
# Iteration:  2
#   current guess is: -2
#   f(guess) is: -22
#
# I set the initial guess to '-4' and the step size to '1'.
# The minimum is -22 when the search stops at x = -2.
# ========================================
# <Global Minimum>
# Iteration:  1
#   current guess is: -3
#   f(guess) is: 0
#
# Iteration:  2
#   current guess is: -2
#   f(guess) is: -22
#
# I set the initial guess to '-4' and the step size to '1'.
# The minimum is -22 when the search stops at x = -2.
# ========================================
# Iteration:  1
#   current guess is: 2
#   f(guess) is: -10
#
# I set the initial guess to '3' and the step size to '1'.
# The minimum is -10 when the search stops at x = 2.
# ========================================
# min([-22, -10]) = -22
#  Therefore, the global miminum is -22.
# ========================================
# <Local Maximum>
# Iteration:  1
#   current guess is: 0
#   f(guess) is: 0
#
# I set the initial guess to '1' and the step size to '1'.
# The maximum is 0 when the search stops at x = 0.
# ========================================
# <Global Maximum>
# Iteration:  1
#   current guess is: 0
#   f(guess) is: 0
#
# I set the initial guess to '1' and the step size to '1'.
# The maximum is 0 when the search stops at x = 0.
# ========================================
# 0

# %%
# func3
print("<<Funcion3>>\n")

print("<Local Minimum>")
finder.set_hp(-2, 1, func_3)
finder.find_nearest_minimum()

print("<Global Minimum>")
finder.set_hp(-2, 1, func_3)
min_1 = finder.find_nearest_minimum()

finder.set_hp(2, 1, func_3)
min_2 = finder.find_nearest_minimum()

global_min = min([min_1, min_2])
print(f"min([{min_1}, {min_2}]) = {global_min} \n Therefore, the global miminum is {global_min}. ")
print("="*40)

print("<Local Maximum>")
finder.set_hp(-1, 1, func_3)
finder.find_nearest_maximum()

print("<Global Maximum>")
finder.set_hp(-1, 1, func_3)
finder.find_nearest_maximum()
# Out:
# <<Funcion3>>
#
# <Local Minimum>
# I set the initial guess to '-2' and the step size to '1'.
# The minimum is -20 when the search stops at x = -2.
# ========================================
# <Global Minimum>
# I set the initial guess to '-2' and the step size to '1'.
# The minimum is -20 when the search stops at x = -2.
# ========================================
# I set the initial guess to '2' and the step size to '1'.
# The minimum is -12 when the search stops at x = 2.
# ========================================
# min([-20, -12]) = -20
#  Therefore, the global miminum is -20.
# ========================================
# <Local Maximum>
# Iteration:  1
#   current guess is: 0
#   f(guess) is: 0
#
# I set the initial guess to '-1' and the step size to '1'.
# The maximum is 0 when the search stops at x = 0.
# ========================================
# <Global Maximum>
# Iteration:  1
#   current guess is: 0
#   f(guess) is: 0
#
# I set the initial guess to '-1' and the step size to '1'.
# The maximum is 0 when the search stops at x = 0.
# ========================================
# 0

# %%
# func4
print("<<Funcion4>>\n")

print("<Local Minimum>")
finder.set_hp(5, 1, func_4)
finder.find_nearest_minimum()

print("<Global Minimum>")
print("此為非負無限大之Global Minimum")
finder.set_hp(5, 1, func_4)
finder.find_nearest_minimum()

print("<Local Maximum>")
finder.set_hp(1, 1, func_4)
finder.find_nearest_maximum()

print("<Global Maximum>")
print("此為非無限大之Global Maximum")
finder.set_hp(1, 1, func_4)
finder.find_nearest_maximum()
# Out:
# <<Funcion4>>
#
# <Local Minimum>
# Iteration:  1
#   current guess is: 6
#   f(guess) is: -8
#
# I set the initial guess to '5' and the step size to '1'.
# The minimum is -8 when the search stops at x = 6.
# ========================================
# <Global Minimum>
# 此為非負無限大之Global Minimum
# Iteration:  1
#   current guess is: 6
#   f(guess) is: -8
#
# I set the initial guess to '5' and the step size to '1'.
# The minimum is -8 when the search stops at x = 6.
# ========================================
# <Local Maximum>
# Iteration:  1
#   current guess is: 2
#   f(guess) is: 8
#
# Iteration:  2
#   current guess is: 3
#   f(guess) is: 13
#
# I set the initial guess to '1' and the step size to '1'.
# The maximum is 13 when the search stops at x = 3.
# ========================================
# <Global Maximum>
# 此為非無限大之Global Maximum
# Iteration:  1
#   current guess is: 2
#   f(guess) is: 8
#
# Iteration:  2
#   current guess is: 3
#   f(guess) is: 13
#
# I set the initial guess to '1' and the step size to '1'.
# The maximum is 13 when the search stops at x = 3.
# ========================================
# 13

# %%
# func5
print("<<Funcion5>>\n")

print("<Local Minimum>")
finder.set_hp(4, 1, func_5)
finder.find_nearest_minimum()

print("<Global Minimum>")
print("此為非負無限大之Global Minimum")
finder.set_hp(4, 1, func_5)
finder.find_nearest_minimum()

print("<Local Maximum>")
finder.set_hp(-1, 1, func_5)
finder.find_nearest_maximum()

print("<Global Maximum>")
print("此為非無限大之Global Maximum")
finder.set_hp(-1, 1, func_5)
finder.find_nearest_maximum()
# Out:
# <<Funcion5>>
#
# <Local Minimum>
# Iteration:  1
#   current guess is: 3
#   f(guess) is: -4
#
# I set the initial guess to '4' and the step size to '1'.
# The minimum is -4 when the search stops at x = 3.
# ========================================
# <Global Minimum>
# 此為非負無限大之Global Minimum
# Iteration:  1
#   current guess is: 3
#   f(guess) is: -4
#
# I set the initial guess to '4' and the step size to '1'.
# The minimum is -4 when the search stops at x = 3.
# ========================================
# <Local Maximum>
# Iteration:  1
#   current guess is: 0
#   f(guess) is: -100
#
# Iteration:  2
#   current guess is: 1
#   f(guess) is: 8
#
# I set the initial guess to '-1' and the step size to '1'.
# The maximum is 8 when the search stops at x = 1.
# ========================================
# <Global Maximum>
# 此為非無限大之Global Maximum
# Iteration:  1
#   current guess is: 0
#   f(guess) is: -100
#
# Iteration:  2
#   current guess is: 1
#   f(guess) is: 8
#
# I set the initial guess to '-1' and the step size to '1'.
# The maximum is 8 when the search stops at x = 1.
# ========================================
# 8

# %%
# 附加問題一：
# 如果限定極值的精確度必須至下數點以下某一個位數，
# 例如小數點以下第三位的話，對於你的答案會有何影響？
print("""
  我有時可以找到更小或更大的極值，手法就是不把step_size設為整數，而是小數
  下面以func_4為例
""")

# step_size = 1
finder.set_hp(5, 1, func_4)
finder.find_nearest_minimum()

# step_size = 0.1
finder.set_hp(5, 0.1, func_4)
finder.find_nearest_minimum()

print("""
  由此可知，當我把小數精度調高，我有可能可以找到更小或更大的極值
""")
# Out:
#   我有時可以找到更小或更大的極值，手法就是不把step_size設為整數，而是小數
#   下面以func_4為例
#
# Iteration:  1
#   current guess is: 6
#   f(guess) is: -8
#
# I set the initial guess to '5' and the step size to '1'.
# The minimum is -8 when the search stops at x = 6.
# ========================================
# Iteration:  1
#   current guess is: 5.1
#   f(guess) is: -1.8890000000000384
#
# Iteration:  2
#   current guess is: 5.199999999999999
#   f(guess) is: -2.7520000000000095
#
# Iteration:  3
#   current guess is: 5.299999999999999
#   f(guess) is: -3.5829999999999984
#
# Iteration:  4
#   current guess is: 5.399999999999999
#   f(guess) is: -4.375999999999976
#
# Iteration:  5
#   current guess is: 5.499999999999998
#   f(guess) is: -5.125000000000057
#
# Iteration:  6
#   current guess is: 5.599999999999998
#   f(guess) is: -5.823999999999955
#
# Iteration:  7
#   current guess is: 5.6999999999999975
#   f(guess) is: -6.4669999999999845
#
# Iteration:  8
#   current guess is: 5.799999999999997
#   f(guess) is: -7.048000000000002
#
# Iteration:  9
#   current guess is: 5.899999999999997
#   f(guess) is: -7.560999999999979
#
# Iteration:  10
#   current guess is: 5.9999999999999964
#   f(guess) is: -8.000000000000057
#
# Iteration:  11
#   current guess is: 6.099999999999996
#   f(guess) is: -8.359000000000037
#
# Iteration:  12
#   current guess is: 6.199999999999996
#   f(guess) is: -8.632000000000005
#
# Iteration:  13
#   current guess is: 6.299999999999995
#   f(guess) is: -8.812999999999988
#
# Iteration:  14
#   current guess is: 6.399999999999995
#   f(guess) is: -8.896000000000015
#
# I set the initial guess to '5' and the step size to '0.1'.
# The minimum is -8.896000000000015 when the search stops at x = 6.399999999999995.
# ========================================
#
#   由此可知，當我把小數精度調高，我有可能可以找到更小或更大的極值

# %%
# 附加問題二：
# 你的答案是否是唯一選擇？有沒有其他可能的設定也能找到答案？
print("""
  不是唯一選擇，根據不同的init_guess與step_size，我可以找到不同的極值
  這關係到你關注的精度，以及初始點不同所找到的局部極值的不同
  附加問題一就是很好的例子
""")
# Out:
#   不是唯一選擇，根據不同的init_guess與step_size，我可以找到不同的極值
#   這關係到你關注的精度，以及初始點不同所找到的局部極值的不同
#   附加問題一就是很好的例子

# %%
# 附加問題三：
# 如果函數有兩個或者兩個以上不同的 local minimum 的話，
# 我們如何找到比較小的 local minimum?
print("""
  在前面找不同函數極值的過程中，我試著去找出所有的local minimum
  而後再從中使用min()函數，找出最小的local minimum
""")
# Out:
#   在前面找不同函數極值的過程中，我試著去找出所有的local minimum
#   而後再從中使用min()函數，找出最小的local minimum

# %%
# 附加問題四：
# 如果 guess= 𝛼 、step_size= 𝛽
# 可以讓自己找到精確到小數點以下第三位的答案，
# 那減小 step_size 的影響為何？增大 step_size 的影響為何？
print("""
  雖然降低step_size的數字大小，可能可以找到更精確的極值
  但代價很明顯，就是計算次數會增多，在這邊的例子，就是iteration次數變多
  導致資源消耗也跟著增多
  下面以fun_5為例
""")

# step_size = 1
finder.set_hp(4, 1, func_5)
finder.find_nearest_minimum()

# step_size = 0.01
finder.set_hp(4, 0.001, func_5)
finder.find_nearest_minimum()

print("""
  由此可知我雖然找到小數點以下第三位答案，但iteration次數大大增加
  從原本的iterate 1次變成iterate 1258次
  這在函數值劇烈變動的函數上尤為明顯，例如func_5
""")
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Iteration:  11
#   current guess is: 3.989000000000001
#   f(guess) is: 89.73080560324888
#
# Iteration:  12
#   current guess is: 3.9880000000000013
#   f(guess) is: 89.526372623111
#
# Iteration:  13
#   current guess is: 3.9870000000000014
#   f(guess) is: 89.32224784423909
#
# Iteration:  14
#   current guess is: 3.9860000000000015
#   f(guess) is: 89.1184309516226
#
# Iteration:  15
#   current guess is: 3.9850000000000017
#   f(guess) is: 88.91492163049088
#
# Iteration:  16
#   current guess is: 3.9840000000000018
#   f(guess) is: 88.7117195663111
#
# Iteration:  17
#   current guess is: 3.983000000000002
#   f(guess) is: 88.50882444479066
#
# Iteration:  18
#   current guess is: 3.982000000000002
#   f(guess) is: 88.30623595187069
#
# Iteration:  19
#   current guess is: 3.981000000000002
#   f(guess) is: 88.10395377373436
#
# Iteration:  20
#   current guess is: 3.980000000000002
#   f(guess) is: 87.90197759680086
#
# Iteration:  21
#   current guess is: 3.9790000000000023
#   f(guess) is: 87.7003071077263
#
# Iteration:  22
#   current guess is: 3.9780000000000024
#   f(guess) is: 87.49894199340724
#
# Iteration:  23
#   current guess is: 3.9770000000000025
#   f(guess) is: 87.29788194097443
#
# Iteration:  24
#   current guess is: 3.9760000000000026
#   f(guess) is: 87.09712663779771
#
# Iteration:  25
#   current guess is: 3.9750000000000028
#   f(guess) is: 86.89667577148487
#
# Iteration:  26
#   current guess is: 3.974000000000003
#   f(guess) is: 86.696529029879
#
# Iteration:  27
#   current guess is: 3.973000000000003
#   f(guess) is: 86.49668610106164
#
# Iteration:  28
#   current guess is: 3.972000000000003
#   f(guess) is: 86.29714667334997
#
# Iteration:  29
#   current guess is: 3.971000000000003
#   f(guess) is: 86.09791043529947
#
# Iteration:  30
#   current guess is: 3.9700000000000033
#   f(guess) is: 85.89897707570083
#
# Iteration:  31
#   current guess is: 3.9690000000000034
#   f(guess) is: 85.70034628358144
#
# Iteration:  32
#   current guess is: 3.9680000000000035
#   f(guess) is: 85.50201774820675
#
# Iteration:  33
#   current guess is: 3.9670000000000036
#   f(guess) is: 85.30399115907562
#
# Iteration:  34
#   current guess is: 3.9660000000000037
#   f(guess) is: 85.10626620592518
#
# Iteration:  35
#   current guess is: 3.965000000000004
#   f(guess) is: 84.90884257872915
#
# Iteration:  36
#   current guess is: 3.964000000000004
#   f(guess) is: 84.71171996769431
#
# Iteration:  37
#   current guess is: 3.963000000000004
#   f(guess) is: 84.51489806326663
#
# Iteration:  38
#   current guess is: 3.962000000000004
#   f(guess) is: 84.31837655612571
#
# Iteration:  39
#   current guess is: 3.9610000000000043
#   f(guess) is: 84.12215513718627
#
# Iteration:  40
#   current guess is: 3.9600000000000044
#   f(guess) is: 83.92623349760095
#
# Iteration:  41
#   current guess is: 3.9590000000000045
#   f(guess) is: 83.73061132875421
#
# Iteration:  42
#   current guess is: 3.9580000000000046
#   f(guess) is: 83.53528832226993
#
# Iteration:  43
#   current guess is: 3.9570000000000047
#   f(guess) is: 83.34026417000246
#
# Iteration:  44
#   current guess is: 3.956000000000005
#   f(guess) is: 83.14553856404473
#
# Iteration:  45
#   current guess is: 3.955000000000005
#   f(guess) is: 82.95111119672276
#
# Iteration:  46
#   current guess is: 3.954000000000005
#   f(guess) is: 82.75698176059802
#
# Iteration:  47
#   current guess is: 3.953000000000005
#   f(guess) is: 82.56314994846662
#
# Iteration:  48
#   current guess is: 3.9520000000000053
#   f(guess) is: 82.36961545335726
#
# Iteration:  49
#   current guess is: 3.9510000000000054
#   f(guess) is: 82.17637796853614
#
# Iteration:  50
#   current guess is: 3.9500000000000055
#   f(guess) is: 81.98343718750095
#
# Iteration:  51
#   current guess is: 3.9490000000000056
#   f(guess) is: 81.79079280398571
#
# Iteration:  52
#   current guess is: 3.9480000000000057
#   f(guess) is: 81.59844451195681
#
# Iteration:  53
#   current guess is: 3.947000000000006
#   f(guess) is: 81.40639200561486
#
# Iteration:  54
#   current guess is: 3.946000000000006
#   f(guess) is: 81.21463497939612
#
# Iteration:  55
#   current guess is: 3.945000000000006
#   f(guess) is: 81.02317312796697
#
# Iteration:  56
#   current guess is: 3.944000000000006
#   f(guess) is: 80.83200614622945
#
# Iteration:  57
#   current guess is: 3.9430000000000063
#   f(guess) is: 80.641133729319
#
# Iteration:  58
#   current guess is: 3.9420000000000064
#   f(guess) is: 80.45055557260457
#
# Iteration:  59
#   current guess is: 3.9410000000000065
#   f(guess) is: 80.26027137168762
#
# Iteration:  60
#   current guess is: 3.9400000000000066
#   f(guess) is: 80.07028082240163
#
# Iteration:  61
#   current guess is: 3.9390000000000067
#   f(guess) is: 79.88058362081495
#
# Iteration:  62
#   current guess is: 3.938000000000007
#   f(guess) is: 79.69117946322842
#
# Iteration:  63
#   current guess is: 3.937000000000007
#   f(guess) is: 79.5020680461746
#
# Iteration:  64
#   current guess is: 3.936000000000007
#   f(guess) is: 79.31324906641976
#
# Iteration:  65
#   current guess is: 3.935000000000007
#   f(guess) is: 79.12472222096017
#
# Iteration:  66
#   current guess is: 3.9340000000000073
#   f(guess) is: 78.93648720702856
#
# Iteration:  67
#   current guess is: 3.9330000000000074
#   f(guess) is: 78.74854372208608
#
# Iteration:  68
#   current guess is: 3.9320000000000075
#   f(guess) is: 78.5608914638276
#
# Iteration:  69
#   current guess is: 3.9310000000000076
#   f(guess) is: 78.37353013017992
#
# Iteration:  70
#   current guess is: 3.9300000000000077
#   f(guess) is: 78.1864594193014
#
# Iteration:  71
#   current guess is: 3.929000000000008
#   f(guess) is: 77.99967902958213
#
# Iteration:  72
#   current guess is: 3.928000000000008
#   f(guess) is: 77.81318865964442
#
# Iteration:  73
#   current guess is: 3.927000000000008
#   f(guess) is: 77.62698800833994
#
# Iteration:  74
#   current guess is: 3.926000000000008
#   f(guess) is: 77.44107677475495
#
# Iteration:  75
#   current guess is: 3.9250000000000083
#   f(guess) is: 77.25545465820483
#
# Iteration:  76
#   current guess is: 3.9240000000000084
#   f(guess) is: 77.07012135823607
#
# Iteration:  77
#   current guess is: 3.9230000000000085
#   f(guess) is: 76.88507657462753
#
# Iteration:  78
#   current guess is: 3.9220000000000086
#   f(guess) is: 76.70032000738718
#
# Iteration:  79
#   current guess is: 3.9210000000000087
#   f(guess) is: 76.51585135675487
#
# Iteration:  80
#   current guess is: 3.920000000000009
#   f(guess) is: 76.33167032320193
#
# Iteration:  81
#   current guess is: 3.919000000000009
#   f(guess) is: 76.1477766074272
#
# Iteration:  82
#   current guess is: 3.918000000000009
#   f(guess) is: 75.9641699103637
#
# Iteration:  83
#   current guess is: 3.917000000000009
#   f(guess) is: 75.78084993317077
#
# Iteration:  84
#   current guess is: 3.9160000000000093
#   f(guess) is: 75.59781637724268
#
# Iteration:  85
#   current guess is: 3.9150000000000094
#   f(guess) is: 75.41506894419831
#
# Iteration:  86
#   current guess is: 3.9140000000000095
#   f(guess) is: 75.23260733589177
#
# Iteration:  87
#   current guess is: 3.9130000000000096
#   f(guess) is: 75.0504312544025
#
# Iteration:  88
#   current guess is: 3.9120000000000097
#   f(guess) is: 74.86854040204241
#
# Iteration:  89
#   current guess is: 3.91100000000001
#   f(guess) is: 74.68693448135275
#
# Iteration:  90
#   current guess is: 3.91000000000001
#   f(guess) is: 74.50561319510189
#
# Iteration:  91
#   current guess is: 3.90900000000001
#   f(guess) is: 74.32457624629023
#
# Iteration:  92
#   current guess is: 3.90800000000001
#   f(guess) is: 74.1438233381466
#
# Iteration:  93
#   current guess is: 3.9070000000000102
#   f(guess) is: 73.96335417412831
#
# Iteration:  94
#   current guess is: 3.9060000000000104
#   f(guess) is: 73.78316845792153
#
# Iteration:  95
#   current guess is: 3.9050000000000105
#   f(guess) is: 73.60326589344277
#
# Iteration:  96
#   current guess is: 3.9040000000000106
#   f(guess) is: 73.42364618483498
#
# Iteration:  97
#   current guess is: 3.9030000000000107
#   f(guess) is: 73.24430903647203
#
# Iteration:  98
#   current guess is: 3.902000000000011
#   f(guess) is: 73.06525415295403
#
# Iteration:  99
#   current guess is: 3.901000000000011
#   f(guess) is: 72.88648123911128
#
# Iteration:  100
#   current guess is: 3.900000000000011
#   f(guess) is: 72.70799000000147
#
# Iteration:  101
#   current guess is: 3.899000000000011
#   f(guess) is: 72.5297801409115
#
# Iteration:  102
#   current guess is: 3.8980000000000112
#   f(guess) is: 72.3518513673539
#
# Iteration:  103
#   current guess is: 3.8970000000000113
#   f(guess) is: 72.17420338507134
#
# Iteration:  104
#   current guess is: 3.8960000000000115
#   f(guess) is: 71.9968359000328
#
# Iteration:  105
#   current guess is: 3.8950000000000116
#   f(guess) is: 71.81974861843707
#
# Iteration:  106
#   current guess is: 3.8940000000000117
#   f(guess) is: 71.64294124670596
#
# Iteration:  107
#   current guess is: 3.893000000000012
#   f(guess) is: 71.46641349149445
#
# Iteration:  108
#   current guess is: 3.892000000000012
#   f(guess) is: 71.29016505968048
#
# Iteration:  109
#   current guess is: 3.891000000000012
#   f(guess) is: 71.11419565837252
#
# Iteration:  110
#   current guess is: 3.890000000000012
#   f(guess) is: 70.93850499490225
#
# Iteration:  111
#   current guess is: 3.8890000000000122
#   f(guess) is: 70.76309277683094
#
# Iteration:  112
#   current guess is: 3.8880000000000123
#   f(guess) is: 70.5879587119457
#
# Iteration:  113
#   current guess is: 3.8870000000000124
#   f(guess) is: 70.41310250826018
#
# Iteration:  114
#   current guess is: 3.8860000000000126
#   f(guess) is: 70.23852387401632
#
# Iteration:  115
#   current guess is: 3.8850000000000127
#   f(guess) is: 70.0642225176806
#
# Iteration:  116
#   current guess is: 3.8840000000000128
#   f(guess) is: 69.89019814794528
#
# Iteration:  117
#   current guess is: 3.883000000000013
#   f(guess) is: 69.71645047373204
#
# Iteration:  118
#   current guess is: 3.882000000000013
#   f(guess) is: 69.54297920418458
#
# Iteration:  119
#   current guess is: 3.881000000000013
#   f(guess) is: 69.36978404867625
#
# Iteration:  120
#   current guess is: 3.880000000000013
#   f(guess) is: 69.19686471680222
#
# Iteration:  121
#   current guess is: 3.8790000000000133
#   f(guess) is: 69.02422091838787
#
# Iteration:  122
#   current guess is: 3.8780000000000134
#   f(guess) is: 68.85185236348048
#
# Iteration:  123
#   current guess is: 3.8770000000000135
#   f(guess) is: 68.6797587623555
#
# Iteration:  124
#   current guess is: 3.8760000000000137
#   f(guess) is: 68.5079398255125
#
# Iteration:  125
#   current guess is: 3.8750000000000138
#   f(guess) is: 68.33639526367358
#
# Iteration:  126
#   current guess is: 3.874000000000014
#   f(guess) is: 68.16512478779316
#
# Iteration:  127
#   current guess is: 3.873000000000014
#   f(guess) is: 67.994128109043
#
# Iteration:  128
#   current guess is: 3.872000000000014
#   f(guess) is: 67.82340493882384
#
# Iteration:  129
#   current guess is: 3.871000000000014
#   f(guess) is: 67.65295498876117
#
# Iteration:  130
#   current guess is: 3.8700000000000143
#   f(guess) is: 67.48277797070216
#
# Iteration:  131
#   current guess is: 3.8690000000000144
#   f(guess) is: 67.31287359672308
#
# Iteration:  132
#   current guess is: 3.8680000000000145
#   f(guess) is: 67.14324157911983
#
# Iteration:  133
#   current guess is: 3.8670000000000146
#   f(guess) is: 66.9738816304166
#
# Iteration:  134
#   current guess is: 3.8660000000000148
#   f(guess) is: 66.80479346335937
#
# Iteration:  135
#   current guess is: 3.865000000000015
#   f(guess) is: 66.63597679091788
#
# Iteration:  136
#   current guess is: 3.864000000000015
#   f(guess) is: 66.46743132628865
#
# Iteration:  137
#   current guess is: 3.863000000000015
#   f(guess) is: 66.29915678288842
#
# Iteration:  138
#   current guess is: 3.862000000000015
#   f(guess) is: 66.13115287435949
#
# Iteration:  139
#   current guess is: 3.8610000000000153
#   f(guess) is: 65.963419314568
#
# Iteration:  140
#   current guess is: 3.8600000000000154
#   f(guess) is: 65.79595581760304
#
# Iteration:  141
#   current guess is: 3.8590000000000155
#   f(guess) is: 65.62876209777562
#
# Iteration:  142
#   current guess is: 3.8580000000000156
#   f(guess) is: 65.46183786962331
#
# Iteration:  143
#   current guess is: 3.8570000000000157
#   f(guess) is: 65.29518284790356
#
# Iteration:  144
#   current guess is: 3.856000000000016
#   f(guess) is: 65.12879674759802
#
# Iteration:  145
#   current guess is: 3.855000000000016
#   f(guess) is: 64.9626792839124
#
# Iteration:  146
#   current guess is: 3.854000000000016
#   f(guess) is: 64.79683017227137
#
# Iteration:  147
#   current guess is: 3.853000000000016
#   f(guess) is: 64.6312491283278
#
# Iteration:  148
#   current guess is: 3.8520000000000163
#   f(guess) is: 64.46593586795052
#
# Iteration:  149
#   current guess is: 3.8510000000000164
#   f(guess) is: 64.30089010723691
#
# Iteration:  150
#   current guess is: 3.8500000000000165
#   f(guess) is: 64.13611156250295
#
# Iteration:  151
#   current guess is: 3.8490000000000166
#   f(guess) is: 63.971599950286986
#
# Iteration:  152
#   current guess is: 3.8480000000000167
#   f(guess) is: 63.80735498735055
#
# Iteration:  153
#   current guess is: 3.847000000000017
#   f(guess) is: 63.643376390676735
#
# Iteration:  154
#   current guess is: 3.846000000000017
#   f(guess) is: 63.479663877469875
#
# Iteration:  155
#   current guess is: 3.845000000000017
#   f(guess) is: 63.316217165156104
#
# Iteration:  156
#   current guess is: 3.844000000000017
#   f(guess) is: 63.15303597138313
#
# Iteration:  157
#   current guess is: 3.8430000000000173
#   f(guess) is: 62.990120014020135
#
# Iteration:  158
#   current guess is: 3.8420000000000174
#   f(guess) is: 62.82746901115763
#
# Iteration:  159
#   current guess is: 3.8410000000000175
#   f(guess) is: 62.66508268110806
#
# Iteration:  160
#   current guess is: 3.8400000000000176
#   f(guess) is: 62.50296074240259
#
# Iteration:  161
#   current guess is: 3.8390000000000177
#   f(guess) is: 62.341102913795794
#
# Iteration:  162
#   current guess is: 3.838000000000018
#   f(guess) is: 62.17950891426187
#
# Iteration:  163
#   current guess is: 3.837000000000018
#   f(guess) is: 62.018178462995934
#
# Iteration:  164
#   current guess is: 3.836000000000018
#   f(guess) is: 61.857111279413175
#
# Iteration:  165
#   current guess is: 3.835000000000018
#   f(guess) is: 61.69630708315026
#
# Iteration:  166
#   current guess is: 3.8340000000000183
#   f(guess) is: 61.53576559406224
#
# Iteration:  167
#   current guess is: 3.8330000000000184
#   f(guess) is: 61.375486532227
#
# Iteration:  168
#   current guess is: 3.8320000000000185
#   f(guess) is: 61.21546961794104
#
# Iteration:  169
#   current guess is: 3.8310000000000186
#   f(guess) is: 61.05571457172107
#
# Iteration:  170
#   current guess is: 3.8300000000000187
#   f(guess) is: 60.896221114303444
#
# Iteration:  171
#   current guess is: 3.829000000000019
#   f(guess) is: 60.736988966643594
#
# Iteration:  172
#   current guess is: 3.828000000000019
#   f(guess) is: 60.57801784991784
#
# Iteration:  173
#   current guess is: 3.827000000000019
#   f(guess) is: 60.41930748552079
#
# Iteration:  174
#   current guess is: 3.826000000000019
#   f(guess) is: 60.26085759506839
#
# Iteration:  175
#   current guess is: 3.8250000000000193
#   f(guess) is: 60.1026679003935
#
# Iteration:  176
#   current guess is: 3.8240000000000194
#   f(guess) is: 59.94473812355022
#
# Iteration:  177
#   current guess is: 3.8230000000000195
#   f(guess) is: 59.78706798680855
#
# Iteration:  178
#   current guess is: 3.8220000000000196
#   f(guess) is: 59.62965721266039
#
# Iteration:  179
#   current guess is: 3.8210000000000197
#   f(guess) is: 59.47250552381627
#
# Iteration:  180
#   current guess is: 3.82000000000002
#   f(guess) is: 59.31561264320317
#
# Iteration:  181
#   current guess is: 3.81900000000002
#   f(guess) is: 59.158978293968175
#
# Iteration:  182
#   current guess is: 3.81800000000002
#   f(guess) is: 59.002602199477224
#
# Iteration:  183
#   current guess is: 3.81700000000002
#   f(guess) is: 58.84648408331225
#
# Iteration:  184
#   current guess is: 3.8160000000000203
#   f(guess) is: 58.69062366927608
#
# Iteration:  185
#   current guess is: 3.8150000000000204
#   f(guess) is: 58.53502068138744
#
# Iteration:  186
#   current guess is: 3.8140000000000205
#   f(guess) is: 58.37967484388514
#
# Iteration:  187
#   current guess is: 3.8130000000000206
#   f(guess) is: 58.2245858812239
#
# Iteration:  188
#   current guess is: 3.8120000000000207
#   f(guess) is: 58.06975351807637
#
# Iteration:  189
#   current guess is: 3.811000000000021
#   f(guess) is: 57.91517747933301
#
# Iteration:  190
#   current guess is: 3.810000000000021
#   f(guess) is: 57.76085749010315
#
# Iteration:  191
#   current guess is: 3.809000000000021
#   f(guess) is: 57.60679327571074
#
# Iteration:  192
#   current guess is: 3.808000000000021
#   f(guess) is: 57.452984561700305
#
# Iteration:  193
#   current guess is: 3.8070000000000213
#   f(guess) is: 57.29943107382883
#
# Iteration:  194
#   current guess is: 3.8060000000000214
#   f(guess) is: 57.14613253807454
#
# Iteration:  195
#   current guess is: 3.8050000000000215
#   f(guess) is: 56.99308868063133
#
# Iteration:  196
#   current guess is: 3.8040000000000216
#   f(guess) is: 56.84029922790819
#
# Iteration:  197
#   current guess is: 3.8030000000000217
#   f(guess) is: 56.68776390653193
#
# Iteration:  198
#   current guess is: 3.802000000000022
#   f(guess) is: 56.535482443347746
#
# Iteration:  199
#   current guess is: 3.801000000000022
#   f(guess) is: 56.383454565412535
#
# Iteration:  200
#   current guess is: 3.800000000000022
#   f(guess) is: 56.231680000003166
#
# Iteration:  201
#   current guess is: 3.799000000000022
#   f(guess) is: 56.08015847461286
#
# Iteration:  202
#   current guess is: 3.7980000000000222
#   f(guess) is: 55.92888971694765
#
# Iteration:  203
#   current guess is: 3.7970000000000224
#   f(guess) is: 55.77787345493198
#
# Iteration:  204
#   current guess is: 3.7960000000000225
#   f(guess) is: 55.62710941670662
#
# Iteration:  205
#   current guess is: 3.7950000000000226
#   f(guess) is: 55.476597330625395
#
# Iteration:  206
#   current guess is: 3.7940000000000227
#   f(guess) is: 55.32633692525985
#
# Iteration:  207
#   current guess is: 3.793000000000023
#   f(guess) is: 55.17632792939594
#
# Iteration:  208
#   current guess is: 3.792000000000023
#   f(guess) is: 55.026570072035156
#
# Iteration:  209
#   current guess is: 3.791000000000023
#   f(guess) is: 54.877063082393306
#
# Iteration:  210
#   current guess is: 3.790000000000023
#   f(guess) is: 54.727806689904014
#
# Iteration:  211
#   current guess is: 3.7890000000000232
#   f(guess) is: 54.578800624210885
#
# Iteration:  212
#   current guess is: 3.7880000000000233
#   f(guess) is: 54.43004461517876
#
# Iteration:  213
#   current guess is: 3.7870000000000235
#   f(guess) is: 54.281538392880975
#
# Iteration:  214
#   current guess is: 3.7860000000000236
#   f(guess) is: 54.133281687608815
#
# Iteration:  215
#   current guess is: 3.7850000000000237
#   f(guess) is: 53.985274229869106
#
# Iteration:  216
#   current guess is: 3.784000000000024
#   f(guess) is: 53.837515750378884
#
# Iteration:  217
#   current guess is: 3.783000000000024
#   f(guess) is: 53.6900059800729
#
# Iteration:  218
#   current guess is: 3.782000000000024
#   f(guess) is: 53.5427446500978
#
# Iteration:  219
#   current guess is: 3.781000000000024
#   f(guess) is: 53.395731491816605
#
# Iteration:  220
#   current guess is: 3.7800000000000242
#   f(guess) is: 53.24896623680365
#
# Iteration:  221
#   current guess is: 3.7790000000000243
#   f(guess) is: 53.10244861684885
#
# Iteration:  222
#   current guess is: 3.7780000000000244
#   f(guess) is: 52.95617836395388
#
# Iteration:  223
#   current guess is: 3.7770000000000246
#   f(guess) is: 52.810155210336006
#
# Iteration:  224
#   current guess is: 3.7760000000000247
#   f(guess) is: 52.66437888842461
#
# Iteration:  225
#   current guess is: 3.775000000000025
#   f(guess) is: 52.518849130863146
#
# Iteration:  226
#   current guess is: 3.774000000000025
#   f(guess) is: 52.37356567050608
#
# Iteration:  227
#   current guess is: 3.773000000000025
#   f(guess) is: 52.22852824042377
#
# Iteration:  228
#   current guess is: 3.772000000000025
#   f(guess) is: 52.08373657389734
#
# Iteration:  229
#   current guess is: 3.771000000000025
#   f(guess) is: 51.939190404421424
#
# Iteration:  230
#   current guess is: 3.7700000000000253
#   f(guess) is: 51.79488946570382
#
# Iteration:  231
#   current guess is: 3.7690000000000254
#   f(guess) is: 51.65083349166332
#
# Iteration:  232
#   current guess is: 3.7680000000000256
#   f(guess) is: 51.507022216433256
#
# Iteration:  233
#   current guess is: 3.7670000000000257
#   f(guess) is: 51.36345537435716
#
# Iteration:  234
#   current guess is: 3.7660000000000258
#   f(guess) is: 51.220132699992064
#
# Iteration:  235
#   current guess is: 3.765000000000026
#   f(guess) is: 51.07705392810726
#
# Iteration:  236
#   current guess is: 3.764000000000026
#   f(guess) is: 50.934218793681794
#
# Iteration:  237
#   current guess is: 3.763000000000026
#   f(guess) is: 50.79162703190889
#
# Iteration:  238
#   current guess is: 3.762000000000026
#   f(guess) is: 50.64927837819266
#
# Iteration:  239
#   current guess is: 3.7610000000000263
#   f(guess) is: 50.50717256814801
#
# Iteration:  240
#   current guess is: 3.7600000000000264
#   f(guess) is: 50.36530933760446
#
# Iteration:  241
#   current guess is: 3.7590000000000265
#   f(guess) is: 50.22368842259675
#
# Iteration:  242
#   current guess is: 3.7580000000000267
#   f(guess) is: 50.08230955937654
#
# Iteration:  243
#   current guess is: 3.7570000000000268
#   f(guess) is: 49.94117248440432
#
# Iteration:  244
#   current guess is: 3.756000000000027
#   f(guess) is: 49.80027693435113
#
# Iteration:  245
#   current guess is: 3.755000000000027
#   f(guess) is: 49.65962264610039
#
# Iteration:  246
#   current guess is: 3.754000000000027
#   f(guess) is: 49.519209356744796
#
# Iteration:  247
#   current guess is: 3.753000000000027
#   f(guess) is: 49.37903680358761
#
# Iteration:  248
#   current guess is: 3.7520000000000273
#   f(guess) is: 49.23910472414343
#
# Iteration:  249
#   current guess is: 3.7510000000000274
#   f(guess) is: 49.09941285613752
#
# Iteration:  250
#   current guess is: 3.7500000000000275
#   f(guess) is: 48.959960937503865
#
# Iteration:  251
#   current guess is: 3.7490000000000276
#   f(guess) is: 48.820748706387576
#
# Iteration:  252
#   current guess is: 3.7480000000000278
#   f(guess) is: 48.68177590114351
#
# Iteration:  253
#   current guess is: 3.747000000000028
#   f(guess) is: 48.54304226033753
#
# Iteration:  254
#   current guess is: 3.746000000000028
#   f(guess) is: 48.40454752274297
#
# Iteration:  255
#   current guess is: 3.745000000000028
#   f(guess) is: 48.26629142734464
#
# Iteration:  256
#   current guess is: 3.744000000000028
#   f(guess) is: 48.12827371333651
#
# Iteration:  257
#   current guess is: 3.7430000000000283
#   f(guess) is: 47.99049412012096
#
# Iteration:  258
#   current guess is: 3.7420000000000284
#   f(guess) is: 47.852952387311575
#
# Iteration:  259
#   current guess is: 3.7410000000000285
#   f(guess) is: 47.715648254728535
#
# Iteration:  260
#   current guess is: 3.7400000000000286
#   f(guess) is: 47.57858146240346
#
# Iteration:  261
#   current guess is: 3.7390000000000287
#   f(guess) is: 47.44175175057626
#
# Iteration:  262
#   current guess is: 3.738000000000029
#   f(guess) is: 47.305158859694984
#
# Iteration:  263
#   current guess is: 3.737000000000029
#   f(guess) is: 47.1688025304162
#
# Iteration:  264
#   current guess is: 3.736000000000029
#   f(guess) is: 47.03268250360645
#
# Iteration:  265
#   current guess is: 3.735000000000029
#   f(guess) is: 46.89679852033794
#
# Iteration:  266
#   current guess is: 3.7340000000000293
#   f(guess) is: 46.76115032189546
#
# Iteration:  267
#   current guess is: 3.7330000000000294
#   f(guess) is: 46.62573764976787
#
# Iteration:  268
#   current guess is: 3.7320000000000295
#   f(guess) is: 46.49056024565425
#
# Iteration:  269
#   current guess is: 3.7310000000000296
#   f(guess) is: 46.35561785146126
#
# Iteration:  270
#   current guess is: 3.7300000000000297
#   f(guess) is: 46.22091020930418
#
# Iteration:  271
#   current guess is: 3.72900000000003
#   f(guess) is: 46.08643706150383
#
# Iteration:  272
#   current guess is: 3.72800000000003
#   f(guess) is: 45.952198150590675
#
# Iteration:  273
#   current guess is: 3.72700000000003
#   f(guess) is: 45.81819321930129
#
# Iteration:  274
#   current guess is: 3.72600000000003
#   f(guess) is: 45.68442201058167
#
# Iteration:  275
#   current guess is: 3.7250000000000303
#   f(guess) is: 45.550884267582546
#
# Iteration:  276
#   current guess is: 3.7240000000000304
#   f(guess) is: 45.41757973366293
#
# Iteration:  277
#   current guess is: 3.7230000000000305
#   f(guess) is: 45.28450815238898
#
# Iteration:  278
#   current guess is: 3.7220000000000306
#   f(guess) is: 45.151669267533634
#
# Iteration:  279
#   current guess is: 3.7210000000000307
#   f(guess) is: 45.0190628230763
#
# Iteration:  280
#   current guess is: 3.720000000000031
#   f(guess) is: 44.886688563204075
#
# Iteration:  281
#   current guess is: 3.719000000000031
#   f(guess) is: 44.754546232308826
#
# Iteration:  282
#   current guess is: 3.718000000000031
#   f(guess) is: 44.62263557498932
#
# Iteration:  283
#   current guess is: 3.717000000000031
#   f(guess) is: 44.49095633605248
#
# Iteration:  284
#   current guess is: 3.7160000000000313
#   f(guess) is: 44.35950826050862
#
# Iteration:  285
#   current guess is: 3.7150000000000314
#   f(guess) is: 44.22829109357633
#
# Iteration:  286
#   current guess is: 3.7140000000000315
#   f(guess) is: 44.09730458067804
#
# Iteration:  287
#   current guess is: 3.7130000000000316
#   f(guess) is: 43.96654846744377
#
# Iteration:  288
#   current guess is: 3.7120000000000317
#   f(guess) is: 43.836022499709316
#
# Iteration:  289
#   current guess is: 3.711000000000032
#   f(guess) is: 43.7057264235134
#
# Iteration:  290
#   current guess is: 3.710000000000032
#   f(guess) is: 43.57565998510415
#
# Iteration:  291
#   current guess is: 3.709000000000032
#   f(guess) is: 43.44582293093151
#
# Iteration:  292
#   current guess is: 3.708000000000032
#   f(guess) is: 43.316215007653
#
# Iteration:  293
#   current guess is: 3.7070000000000323
#   f(guess) is: 43.18683596212941
#
# Iteration:  294
#   current guess is: 3.7060000000000324
#   f(guess) is: 43.057685541427645
#
# Iteration:  295
#   current guess is: 3.7050000000000325
#   f(guess) is: 42.928763492819485
#
# Iteration:  296
#   current guess is: 3.7040000000000326
#   f(guess) is: 42.80006956378122
#
# Iteration:  297
#   current guess is: 3.7030000000000327
#   f(guess) is: 42.67160350199299
#
# Iteration:  298
#   current guess is: 3.702000000000033
#   f(guess) is: 42.54336505534047
#
# Iteration:  299
#   current guess is: 3.701000000000033
#   f(guess) is: 42.41535397191251
#
# Iteration:  300
#   current guess is: 3.700000000000033
#   f(guess) is: 42.287570000003825
#
# Iteration:  301
#   current guess is: 3.699000000000033
#   f(guess) is: 42.16001288811265
#
# Iteration:  302
#   current guess is: 3.6980000000000333
#   f(guess) is: 42.0326823849399
#
# Iteration:  303
#   current guess is: 3.6970000000000334
#   f(guess) is: 41.90557823939275
#
# Iteration:  304
#   current guess is: 3.6960000000000335
#   f(guess) is: 41.778700200579124
#
# Iteration:  305
#   current guess is: 3.6950000000000336
#   f(guess) is: 41.65204801781397
#
# Iteration:  306
#   current guess is: 3.6940000000000337
#   f(guess) is: 41.525621440612554
#
# Iteration:  307
#   current guess is: 3.693000000000034
#   f(guess) is: 41.39942021869581
#
# Iteration:  308
#   current guess is: 3.692000000000034
#   f(guess) is: 41.273444101987025
#
# Iteration:  309
#   current guess is: 3.691000000000034
#   f(guess) is: 41.1476928406139
#
# Iteration:  310
#   current guess is: 3.690000000000034
#   f(guess) is: 41.02216618490411
#
# Iteration:  311
#   current guess is: 3.6890000000000343
#   f(guess) is: 40.89686388539178
#
# Iteration:  312
#   current guess is: 3.6880000000000344
#   f(guess) is: 40.77178569281148
#
# Iteration:  313
#   current guess is: 3.6870000000000345
#   f(guess) is: 40.6469313581016
#
# Iteration:  314
#   current guess is: 3.6860000000000346
#   f(guess) is: 40.52230063240245
#
# Iteration:  315
#   current guess is: 3.6850000000000347
#   f(guess) is: 40.3978932670575
#
# Iteration:  316
#   current guess is: 3.684000000000035
#   f(guess) is: 40.273709013612006
#
# Iteration:  317
#   current guess is: 3.683000000000035
#   f(guess) is: 40.14974762381269
#
# Iteration:  318
#   current guess is: 3.682000000000035
#   f(guess) is: 40.02600884961123
#
# Iteration:  319
#   current guess is: 3.681000000000035
#   f(guess) is: 39.90249244315646
#
# Iteration:  320
#   current guess is: 3.6800000000000352
#   f(guess) is: 39.77919815680434
#
# Iteration:  321
#   current guess is: 3.6790000000000354
#   f(guess) is: 39.65612574310876
#
# Iteration:  322
#   current guess is: 3.6780000000000355
#   f(guess) is: 39.53327495482688
#
# Iteration:  323
#   current guess is: 3.6770000000000356
#   f(guess) is: 39.41064554491652
#
# Iteration:  324
#   current guess is: 3.6760000000000357
#   f(guess) is: 39.28823726653786
#
# Iteration:  325
#   current guess is: 3.675000000000036
#   f(guess) is: 39.166049873051634
#
# Iteration:  326
#   current guess is: 3.674000000000036
#   f(guess) is: 39.04408311801899
#
# Iteration:  327
#   current guess is: 3.673000000000036
#   f(guess) is: 38.9223367552039
#
# Iteration:  328
#   current guess is: 3.672000000000036
#   f(guess) is: 38.80081053856986
#
# Iteration:  329
#   current guess is: 3.6710000000000362
#   f(guess) is: 38.67950422228171
#
# Iteration:  330
#   current guess is: 3.6700000000000363
#   f(guess) is: 38.558417560704356
#
# Iteration:  331
#   current guess is: 3.6690000000000365
#   f(guess) is: 38.437550308403615
#
# Iteration:  332
#   current guess is: 3.6680000000000366
#   f(guess) is: 38.31690222014595
#
# Iteration:  333
#   current guess is: 3.6670000000000367
#   f(guess) is: 38.19647305089768
#
# Iteration:  334
#   current guess is: 3.666000000000037
#   f(guess) is: 38.07626255582534
#
# Iteration:  335
#   current guess is: 3.665000000000037
#   f(guess) is: 37.95627049029554
#
# Iteration:  336
#   current guess is: 3.664000000000037
#   f(guess) is: 37.836496609874075
#
# Iteration:  337
#   current guess is: 3.663000000000037
#   f(guess) is: 37.716940670328995
#
# Iteration:  338
#   current guess is: 3.6620000000000372
#   f(guess) is: 37.59760242762479
#
# Iteration:  339
#   current guess is: 3.6610000000000373
#   f(guess) is: 37.47848163792912
#
# Iteration:  340
#   current guess is: 3.6600000000000374
#   f(guess) is: 37.35957805760427
#
# Iteration:  341
#   current guess is: 3.6590000000000376
#   f(guess) is: 37.240891443216924
#
# Iteration:  342
#   current guess is: 3.6580000000000377
#   f(guess) is: 37.12242155152899
#
# Iteration:  343
#   current guess is: 3.6570000000000378
#   f(guess) is: 37.00416813950426
#
# Iteration:  344
#   current guess is: 3.656000000000038
#   f(guess) is: 36.88613096430424
#
# Iteration:  345
#   current guess is: 3.655000000000038
#   f(guess) is: 36.76830978328883
#
# Iteration:  346
#   current guess is: 3.654000000000038
#   f(guess) is: 36.650704354017535
#
# Iteration:  347
#   current guess is: 3.653000000000038
#   f(guess) is: 36.53331443424781
#
# Iteration:  348
#   current guess is: 3.6520000000000383
#   f(guess) is: 36.416139781936636
#
# Iteration:  349
#   current guess is: 3.6510000000000384
#   f(guess) is: 36.29918015523788
#
# Iteration:  350
#   current guess is: 3.6500000000000385
#   f(guess) is: 36.18243531250448
#
# Iteration:  351
#   current guess is: 3.6490000000000387
#   f(guess) is: 36.065905012287885
#
# Iteration:  352
#   current guess is: 3.6480000000000388
#   f(guess) is: 35.94958901333666
#
# Iteration:  353
#   current guess is: 3.647000000000039
#   f(guess) is: 35.83348707459777
#
# Iteration:  354
#   current guess is: 3.646000000000039
#   f(guess) is: 35.71759895521507
#
# Iteration:  355
#   current guess is: 3.645000000000039
#   f(guess) is: 35.601924414532846
#
# Iteration:  356
#   current guess is: 3.644000000000039
#   f(guess) is: 35.48646321208844
#
# Iteration:  357
#   current guess is: 3.6430000000000393
#   f(guess) is: 35.37121510762131
#
# Iteration:  358
#   current guess is: 3.6420000000000394
#   f(guess) is: 35.256179861063856
#
# Iteration:  359
#   current guess is: 3.6410000000000395
#   f(guess) is: 35.14135723254856
#
# Iteration:  360
#   current guess is: 3.6400000000000396
#   f(guess) is: 35.02674698240446
#
# Iteration:  361
#   current guess is: 3.6390000000000398
#   f(guess) is: 34.912348871156496
#
# Iteration:  362
#   current guess is: 3.63800000000004
#   f(guess) is: 34.79816265952809
#
# Iteration:  363
#   current guess is: 3.63700000000004
#   f(guess) is: 34.684188108436274
#
# Iteration:  364
#   current guess is: 3.63600000000004
#   f(guess) is: 34.570424978998744
#
# Iteration:  365
#   current guess is: 3.63500000000004
#   f(guess) is: 34.45687303252623
#
# Iteration:  366
#   current guess is: 3.6340000000000403
#   f(guess) is: 34.343532030527854
#
# Iteration:  367
#   current guess is: 3.6330000000000404
#   f(guess) is: 34.230401734708266
#
# Iteration:  368
#   current guess is: 3.6320000000000405
#   f(guess) is: 34.11748190696676
#
# Iteration:  369
#   current guess is: 3.6310000000000406
#   f(guess) is: 34.00477230940169
#
# Iteration:  370
#   current guess is: 3.6300000000000407
#   f(guess) is: 33.89227270430467
#
# Iteration:  371
#   current guess is: 3.629000000000041
#   f(guess) is: 33.77998285416368
#
# Iteration:  372
#   current guess is: 3.628000000000041
#   f(guess) is: 33.667902521662654
#
# Iteration:  373
#   current guess is: 3.627000000000041
#   f(guess) is: 33.55603146968156
#
# Iteration:  374
#   current guess is: 3.626000000000041
#   f(guess) is: 33.44436946129417
#
# Iteration:  375
#   current guess is: 3.6250000000000413
#   f(guess) is: 33.33291625977006
#
# Iteration:  376
#   current guess is: 3.6240000000000414
#   f(guess) is: 33.22167162857511
#
# Iteration:  377
#   current guess is: 3.6230000000000415
#   f(guess) is: 33.1106353313686
#
# Iteration:  378
#   current guess is: 3.6220000000000416
#   f(guess) is: 32.999807132006254
#
# Iteration:  379
#   current guess is: 3.6210000000000417
#   f(guess) is: 32.88918679453673
#
# Iteration:  380
#   current guess is: 3.620000000000042
#   f(guess) is: 32.778774083204326
#
# Iteration:  381
#   current guess is: 3.619000000000042
#   f(guess) is: 32.668568762448444
#
# Iteration:  382
#   current guess is: 3.618000000000042
#   f(guess) is: 32.558570596902086
#
# Iteration:  383
#   current guess is: 3.617000000000042
#   f(guess) is: 32.44877935139243
#
# Iteration:  384
#   current guess is: 3.6160000000000423
#   f(guess) is: 32.33919479094129
#
# Iteration:  385
#   current guess is: 3.6150000000000424
#   f(guess) is: 32.22981668076363
#
# Iteration:  386
#   current guess is: 3.6140000000000425
#   f(guess) is: 32.12064478627042
#
# Iteration:  387
#   current guess is: 3.6130000000000426
#   f(guess) is: 32.01167887306417
#
# Iteration:  388
#   current guess is: 3.6120000000000427
#   f(guess) is: 31.902918706941136
#
# Iteration:  389
#   current guess is: 3.611000000000043
#   f(guess) is: 31.79436405389356
#
# Iteration:  390
#   current guess is: 3.610000000000043
#   f(guess) is: 31.68601468010479
#
# Iteration:  391
#   current guess is: 3.609000000000043
#   f(guess) is: 31.57787035195213
#
# Iteration:  392
#   current guess is: 3.608000000000043
#   f(guess) is: 31.469930836005574
#
# Iteration:  393
#   current guess is: 3.6070000000000433
#   f(guess) is: 31.362195899029643
#
# Iteration:  394
#   current guess is: 3.6060000000000434
#   f(guess) is: 31.25466530797985
#
# Iteration:  395
#   current guess is: 3.6050000000000435
#   f(guess) is: 31.14733883000804
#
# Iteration:  396
#   current guess is: 3.6040000000000436
#   f(guess) is: 31.04021623245353
#
# Iteration:  397
#   current guess is: 3.6030000000000437
#   f(guess) is: 30.93329728285255
#
# Iteration:  398
#   current guess is: 3.602000000000044
#   f(guess) is: 30.826581748932426
#
# Iteration:  399
#   current guess is: 3.601000000000044
#   f(guess) is: 30.720069398612395
#
# Iteration:  400
#   current guess is: 3.600000000000044
#   f(guess) is: 30.613760000004277
#
# Iteration:  401
#   current guess is: 3.599000000000044
#   f(guess) is: 30.507653321412363
#
# Iteration:  402
#   current guess is: 3.5980000000000443
#   f(guess) is: 30.401749131332622
#
# Iteration:  403
#   current guess is: 3.5970000000000444
#   f(guess) is: 30.296047198452584
#
# Iteration:  404
#   current guess is: 3.5960000000000445
#   f(guess) is: 30.190547291651228
#
# Iteration:  405
#   current guess is: 3.5950000000000446
#   f(guess) is: 30.08524918000171
#
# Iteration:  406
#   current guess is: 3.5940000000000447
#   f(guess) is: 29.98015263276511
#
# Iteration:  407
#   current guess is: 3.593000000000045
#   f(guess) is: 29.875257419396462
#
# Iteration:  408
#   current guess is: 3.592000000000045
#   f(guess) is: 29.770563309539853
#
# Iteration:  409
#   current guess is: 3.591000000000045
#   f(guess) is: 29.66607007303344
#
# Iteration:  410
#   current guess is: 3.590000000000045
#   f(guess) is: 29.561777479905004
#
# Iteration:  411
#   current guess is: 3.5890000000000453
#   f(guess) is: 29.457685300371395
#
# Iteration:  412
#   current guess is: 3.5880000000000454
#   f(guess) is: 29.353793304843748
#
# Iteration:  413
#   current guess is: 3.5870000000000455
#   f(guess) is: 29.250101263921238
#
# Iteration:  414
#   current guess is: 3.5860000000000456
#   f(guess) is: 29.146608948394828
#
# Iteration:  415
#   current guess is: 3.5850000000000457
#   f(guess) is: 29.043316129245113
#
# Iteration:  416
#   current guess is: 3.584000000000046
#   f(guess) is: 28.940222577644363
#
# Iteration:  417
#   current guess is: 3.583000000000046
#   f(guess) is: 28.837328064953
#
# Iteration:  418
#   current guess is: 3.582000000000046
#   f(guess) is: 28.73463236272289
#
# Iteration:  419
#   current guess is: 3.581000000000046
#   f(guess) is: 28.632135242696336
#
# Iteration:  420
#   current guess is: 3.5800000000000463
#   f(guess) is: 28.529836476804803
#
# Iteration:  421
#   current guess is: 3.5790000000000464
#   f(guess) is: 28.42773583716871
#
# Iteration:  422
#   current guess is: 3.5780000000000465
#   f(guess) is: 28.32583309609913
#
# Iteration:  423
#   current guess is: 3.5770000000000466
#   f(guess) is: 28.224128026095855
#
# Iteration:  424
#   current guess is: 3.5760000000000467
#   f(guess) is: 28.122620399850234
#
# Iteration:  425
#   current guess is: 3.575000000000047
#   f(guess) is: 28.0213099902395
#
# Iteration:  426
#   current guess is: 3.574000000000047
#   f(guess) is: 27.920196570330745
#
# Iteration:  427
#   current guess is: 3.573000000000047
#   f(guess) is: 27.819279913383753
#
# Iteration:  428
#   current guess is: 3.572000000000047
#   f(guess) is: 27.718559792842598
#
# Iteration:  429
#   current guess is: 3.5710000000000472
#   f(guess) is: 27.61803598234144
#
# Iteration:  430
#   current guess is: 3.5700000000000474
#   f(guess) is: 27.51770825570486
#
# Iteration:  431
#   current guess is: 3.5690000000000475
#   f(guess) is: 27.417576386943438
#
# Iteration:  432
#   current guess is: 3.5680000000000476
#   f(guess) is: 27.317640150258285
#
# Iteration:  433
#   current guess is: 3.5670000000000477
#   f(guess) is: 27.217899320037077
#
# Iteration:  434
#   current guess is: 3.566000000000048
#   f(guess) is: 27.118353670857346
#
# Iteration:  435
#   current guess is: 3.565000000000048
#   f(guess) is: 27.01900297748341
#
# Iteration:  436
#   current guess is: 3.564000000000048
#   f(guess) is: 26.91984701486672
#
# Iteration:  437
#   current guess is: 3.563000000000048
#   f(guess) is: 26.820885558148802
#
# Iteration:  438
#   current guess is: 3.5620000000000482
#   f(guess) is: 26.72211838265821
#
# Iteration:  439
#   current guess is: 3.5610000000000483
#   f(guess) is: 26.623545263908568
#
# Iteration:  440
#   current guess is: 3.5600000000000485
#   f(guess) is: 26.525165977604843
#
# Iteration:  441
#   current guess is: 3.5590000000000486
#   f(guess) is: 26.42698029963674
#
# Iteration:  442
#   current guess is: 3.5580000000000487
#   f(guess) is: 26.328988006081772
#
# Iteration:  443
#   current guess is: 3.557000000000049
#   f(guess) is: 26.231188873204474
#
# Iteration:  444
#   current guess is: 3.556000000000049
#   f(guess) is: 26.133582677456616
#
# Iteration:  445
#   current guess is: 3.555000000000049
#   f(guess) is: 26.036169195476646
#
# Iteration:  446
#   current guess is: 3.554000000000049
#   f(guess) is: 25.938948204089797
#
# Iteration:  447
#   current guess is: 3.5530000000000492
#   f(guess) is: 25.841919480307524
#
# Iteration:  448
#   current guess is: 3.5520000000000493
#   f(guess) is: 25.745082801328863
#
# Iteration:  449
#   current guess is: 3.5510000000000495
#   f(guess) is: 25.648437944537363
#
# Iteration:  450
#   current guess is: 3.5500000000000496
#   f(guess) is: 25.55198468750484
#
# Iteration:  451
#   current guess is: 3.5490000000000497
#   f(guess) is: 25.45572280798808
#
# Iteration:  452
#   current guess is: 3.54800000000005
#   f(guess) is: 25.359652083928268
#
# Iteration:  453
#   current guess is: 3.54700000000005
#   f(guess) is: 25.263772293456668
#
# Iteration:  454
#   current guess is: 3.54600000000005
#   f(guess) is: 25.1680832148877
#
# Iteration:  455
#   current guess is: 3.54500000000005
#   f(guess) is: 25.072584626720186
#
# Iteration:  456
#   current guess is: 3.54400000000005
#   f(guess) is: 24.977276307640636
#
# Iteration:  457
#   current guess is: 3.5430000000000503
#   f(guess) is: 24.882158036520764
#
# Iteration:  458
#   current guess is: 3.5420000000000504
#   f(guess) is: 24.78722959241577
#
# Iteration:  459
#   current guess is: 3.5410000000000506
#   f(guess) is: 24.69249075456878
#
# Iteration:  460
#   current guess is: 3.5400000000000507
#   f(guess) is: 24.59794130240448
#
# Iteration:  461
#   current guess is: 3.5390000000000508
#   f(guess) is: 24.503581015536497
#
# Iteration:  462
#   current guess is: 3.538000000000051
#   f(guess) is: 24.409409673760024
#
# Iteration:  463
#   current guess is: 3.537000000000051
#   f(guess) is: 24.31542705705624
#
# Iteration:  464
#   current guess is: 3.536000000000051
#   f(guess) is: 24.221632945591182
#
# Iteration:  465
#   current guess is: 3.535000000000051
#   f(guess) is: 24.128027119713806
#
# Iteration:  466
#   current guess is: 3.5340000000000513
#   f(guess) is: 24.0346093599602
#
# Iteration:  467
#   current guess is: 3.5330000000000514
#   f(guess) is: 23.94137944704778
#
# Iteration:  468
#   current guess is: 3.5320000000000515
#   f(guess) is: 23.8483371618795
#
# Iteration:  469
#   current guess is: 3.5310000000000517
#   f(guess) is: 23.75548228554112
#
# Iteration:  470
#   current guess is: 3.5300000000000518
#   f(guess) is: 23.662814599305193
#
# Iteration:  471
#   current guess is: 3.529000000000052
#   f(guess) is: 23.570333884622983
#
# Iteration:  472
#   current guess is: 3.528000000000052
#   f(guess) is: 23.478039923135498
#
# Iteration:  473
#   current guess is: 3.527000000000052
#   f(guess) is: 23.38593249666144
#
# Iteration:  474
#   current guess is: 3.526000000000052
#   f(guess) is: 23.294011387206183
#
# Iteration:  475
#   current guess is: 3.5250000000000523
#   f(guess) is: 23.20227637695757
#
# Iteration:  476
#   current guess is: 3.5240000000000524
#   f(guess) is: 23.110727248287503
#
# Iteration:  477
#   current guess is: 3.5230000000000525
#   f(guess) is: 23.019363783748872
#
# Iteration:  478
#   current guess is: 3.5220000000000526
#   f(guess) is: 22.928185766078172
#
# Iteration:  479
#   current guess is: 3.5210000000000528
#   f(guess) is: 22.8371929781963
#
# Iteration:  480
#   current guess is: 3.520000000000053
#   f(guess) is: 22.746385203205136
#
# Iteration:  481
#   current guess is: 3.519000000000053
#   f(guess) is: 22.655762224388354
#
# Iteration:  482
#   current guess is: 3.518000000000053
#   f(guess) is: 22.565323825214477
#
# Iteration:  483
#   current guess is: 3.517000000000053
#   f(guess) is: 22.475069789331997
#
# Iteration:  484
#   current guess is: 3.5160000000000533
#   f(guess) is: 22.384999900573575
#
# Iteration:  485
#   current guess is: 3.5150000000000534
#   f(guess) is: 22.29511394295173
#
# Iteration:  486
#   current guess is: 3.5140000000000535
#   f(guess) is: 22.20541170066258
#
# Iteration:  487
#   current guess is: 3.5130000000000536
#   f(guess) is: 22.11589295808369
#
# Iteration:  488
#   current guess is: 3.5120000000000537
#   f(guess) is: 22.026557499773958
#
# Iteration:  489
#   current guess is: 3.511000000000054
#   f(guess) is: 21.937405110473378
#
# Iteration:  490
#   current guess is: 3.510000000000054
#   f(guess) is: 21.84843557510453
#
# Iteration:  491
#   current guess is: 3.509000000000054
#   f(guess) is: 21.759648678771555
#
# Iteration:  492
#   current guess is: 3.508000000000054
#   f(guess) is: 21.671044206757642
#
# Iteration:  493
#   current guess is: 3.5070000000000543
#   f(guess) is: 21.582621944529023
#
# Iteration:  494
#   current guess is: 3.5060000000000544
#   f(guess) is: 21.494381677732804
#
# Iteration:  495
#   current guess is: 3.5050000000000545
#   f(guess) is: 21.406323192195487
#
# Iteration:  496
#   current guess is: 3.5040000000000546
#   f(guess) is: 21.318446273925247
#
# Iteration:  497
#   current guess is: 3.5030000000000547
#   f(guess) is: 21.2307507091125
#
# Iteration:  498
#   current guess is: 3.502000000000055
#   f(guess) is: 21.143236284124328
#
# Iteration:  499
#   current guess is: 3.501000000000055
#   f(guess) is: 21.055902785512103
#
# Iteration:  500
#   current guess is: 3.500000000000055
#   f(guess) is: 20.968750000004775
#
# Iteration:  501
#   current guess is: 3.499000000000055
#   f(guess) is: 20.881777714512054
#
# Iteration:  502
#   current guess is: 3.4980000000000553
#   f(guess) is: 20.794985716124984
#
# Iteration:  503
#   current guess is: 3.4970000000000554
#   f(guess) is: 20.708373792112184
#
# Iteration:  504
#   current guess is: 3.4960000000000555
#   f(guess) is: 20.62194172992406
#
# Iteration:  505
#   current guess is: 3.4950000000000556
#   f(guess) is: 20.53568931718962
#
# Iteration:  506
#   current guess is: 3.4940000000000557
#   f(guess) is: 20.449616341717046
#
# Iteration:  507
#   current guess is: 3.493000000000056
#   f(guess) is: 20.363722591495844
#
# Iteration:  508
#   current guess is: 3.492000000000056
#   f(guess) is: 20.278007854692305
#
# Iteration:  509
#   current guess is: 3.491000000000056
#   f(guess) is: 20.192471919653713
#
# Iteration:  510
#   current guess is: 3.490000000000056
#   f(guess) is: 20.107114574904585
#
# Iteration:  511
#   current guess is: 3.4890000000000563
#   f(guess) is: 20.021935609151114
#
# Iteration:  512
#   current guess is: 3.4880000000000564
#   f(guess) is: 19.93693481127616
#
# Iteration:  513
#   current guess is: 3.4870000000000565
#   f(guess) is: 19.852111970340957
#
# Iteration:  514
#   current guess is: 3.4860000000000566
#   f(guess) is: 19.76746687558682
#
# Iteration:  515
#   current guess is: 3.4850000000000567
#   f(guess) is: 19.68299931643321
#
# Iteration:  516
#   current guess is: 3.484000000000057
#   f(guess) is: 19.598709082476034
#
# Iteration:  517
#   current guess is: 3.483000000000057
#   f(guess) is: 19.514595963491956
#
# Iteration:  518
#   current guess is: 3.482000000000057
#   f(guess) is: 19.430659749435335
#
# Iteration:  519
#   current guess is: 3.481000000000057
#   f(guess) is: 19.346900230435608
#
# Iteration:  520
#   current guess is: 3.4800000000000573
#   f(guess) is: 19.263317196804906
#
# Iteration:  521
#   current guess is: 3.4790000000000574
#   f(guess) is: 19.179910439028276
#
# Iteration:  522
#   current guess is: 3.4780000000000575
#   f(guess) is: 19.096679747771077
#
# Iteration:  523
#   current guess is: 3.4770000000000576
#   f(guess) is: 19.01362491387613
#
# Iteration:  524
#   current guess is: 3.4760000000000577
#   f(guess) is: 18.930745728362126
#
# Iteration:  525
#   current guess is: 3.475000000000058
#   f(guess) is: 18.84804198242648
#
# Iteration:  526
#   current guess is: 3.474000000000058
#   f(guess) is: 18.765513467443157
#
# Iteration:  527
#   current guess is: 3.473000000000058
#   f(guess) is: 18.683159974963473
#
# Iteration:  528
#   current guess is: 3.472000000000058
#   f(guess) is: 18.600981296714508
#
# Iteration:  529
#   current guess is: 3.4710000000000583
#   f(guess) is: 18.51897722460103
#
# Iteration:  530
#   current guess is: 3.4700000000000584
#   f(guess) is: 18.43714755070448
#
# Iteration:  531
#   current guess is: 3.4690000000000585
#   f(guess) is: 18.35549206728308
#
# Iteration:  532
#   current guess is: 3.4680000000000586
#   f(guess) is: 18.274010566770357
#
# Iteration:  533
#   current guess is: 3.4670000000000587
#   f(guess) is: 18.192702841776963
#
# Iteration:  534
#   current guess is: 3.466000000000059
#   f(guess) is: 18.11156868508965
#
# ...
#   current guess is: 2.90900000000012
#   f(guess) is: -5.447788498515251
#
# Iteration:  1092
#   current guess is: 2.9080000000001203
#   f(guess) is: -5.459750218333966
#
# Iteration:  1093
#   current guess is: 2.9070000000001204
#   f(guess) is: -5.47163014187754
#
# Iteration:  1094
#   current guess is: 2.9060000000001205
#   f(guess) is: -5.4834283965585655
#
# Iteration:  1095
#   current guess is: 2.9050000000001206
#   f(guess) is: -5.495145109682994
#
# Iteration:  1096
#   current guess is: 2.9040000000001207
#   f(guess) is: -5.506780408445479
#
# Iteration:  1097
#   current guess is: 2.903000000000121
#   f(guess) is: -5.518334419933808
#
# Iteration:  1098
#   current guess is: 2.902000000000121
#   f(guess) is: -5.529807271126629
#
# Iteration:  1099
#   current guess is: 2.901000000000121
#   f(guess) is: -5.541199088893791
#
# Iteration:  1100
#   current guess is: 2.900000000000121
#   f(guess) is: -5.5525099999982785
#
# Iteration:  1101
#   current guess is: 2.8990000000001213
#   f(guess) is: -5.5637401310943915
#
# Iteration:  1102
#   current guess is: 2.8980000000001214
#   f(guess) is: -5.574889608726494
#
# Iteration:  1103
#   current guess is: 2.8970000000001215
#   f(guess) is: -5.5859585593342445
#
# Iteration:  1104
#   current guess is: 2.8960000000001216
#   f(guess) is: -5.596947109247822
#
# Iteration:  1105
#   current guess is: 2.8950000000001217
#   f(guess) is: -5.60785538468906
#
# Iteration:  1106
#   current guess is: 2.894000000000122
#   f(guess) is: -5.618683511774407
#
# Iteration:  1107
#   current guess is: 2.893000000000122
#   f(guess) is: -5.6294316165108285
#
# Iteration:  1108
#   current guess is: 2.892000000000122
#   f(guess) is: -5.640099824799336
#
# Iteration:  1109
#   current guess is: 2.891000000000122
#   f(guess) is: -5.65068826243305
#
# Iteration:  1110
#   current guess is: 2.8900000000001222
#   f(guess) is: -5.6611970550986825
#
# Iteration:  1111
#   current guess is: 2.8890000000001224
#   f(guess) is: -5.671626328375396
#
# Iteration:  1112
#   current guess is: 2.8880000000001225
#   f(guess) is: -5.681976207735374
#
# Iteration:  1113
#   current guess is: 2.8870000000001226
#   f(guess) is: -5.6922468185453
#
# Iteration:  1114
#   current guess is: 2.8860000000001227
#   f(guess) is: -5.702438286064762
#
# Iteration:  1115
#   current guess is: 2.885000000000123
#   f(guess) is: -5.712550735445575
#
# Iteration:  1116
#   current guess is: 2.884000000000123
#   f(guess) is: -5.722584291735302
#
# Iteration:  1117
#   current guess is: 2.883000000000123
#   f(guess) is: -5.732539079874414
#
# Iteration:  1118
#   current guess is: 2.882000000000123
#   f(guess) is: -5.742415224696401
#
# Iteration:  1119
#   current guess is: 2.8810000000001232
#   f(guess) is: -5.752212850930505
#
# Iteration:  1120
#   current guess is: 2.8800000000001234
#   f(guess) is: -5.761932083198531
#
# Iteration:  1121
#   current guess is: 2.8790000000001235
#   f(guess) is: -5.771573046018489
#
# Iteration:  1122
#   current guess is: 2.8780000000001236
#   f(guess) is: -5.7811358638005
#
# Iteration:  1123
#   current guess is: 2.8770000000001237
#   f(guess) is: -5.790620660850436
#
# Iteration:  1124
#   current guess is: 2.876000000000124
#   f(guess) is: -5.8000275613696886
#
# Iteration:  1125
#   current guess is: 2.875000000000124
#   f(guess) is: -5.809356689451988
#
# Iteration:  1126
#   current guess is: 2.874000000000124
#   f(guess) is: -5.81860816908852
#
# Iteration:  1127
#   current guess is: 2.873000000000124
#   f(guess) is: -5.827782124163377
#
# Iteration:  1128
#   current guess is: 2.8720000000001242
#   f(guess) is: -5.836878678457197
#
# Iteration:  1129
#   current guess is: 2.8710000000001243
#   f(guess) is: -5.845897955645455
#
# Iteration:  1130
#   current guess is: 2.8700000000001245
#   f(guess) is: -5.854840079299038
#
# Iteration:  1131
#   current guess is: 2.8690000000001246
#   f(guess) is: -5.863705172883442
#
# Iteration:  1132
#   current guess is: 2.8680000000001247
#   f(guess) is: -5.872493359761052
#
# Iteration:  1133
#   current guess is: 2.867000000000125
#   f(guess) is: -5.881204763189885
#
# Iteration:  1134
#   current guess is: 2.866000000000125
#   f(guess) is: -5.889839506322346
#
# Iteration:  1135
#   current guess is: 2.865000000000125
#   f(guess) is: -5.898397712208407
#
# Iteration:  1136
#   current guess is: 2.864000000000125
#   f(guess) is: -5.906879503792993
#
# Iteration:  1137
#   current guess is: 2.8630000000001252
#   f(guess) is: -5.915285003918257
#
# Iteration:  1138
#   current guess is: 2.8620000000001253
#   f(guess) is: -5.923614335322213
#
# Iteration:  1139
#   current guess is: 2.8610000000001254
#   f(guess) is: -5.931867620638741
#
# Iteration:  1140
#   current guess is: 2.8600000000001256
#   f(guess) is: -5.940044982399172
#
# Iteration:  1141
#   current guess is: 2.8590000000001257
#   f(guess) is: -5.948146543031044
#
# Iteration:  1142
#   current guess is: 2.8580000000001258
#   f(guess) is: -5.956172424857982
#
# Iteration:  1143
#   current guess is: 2.857000000000126
#   f(guess) is: -5.964122750103002
#
# Iteration:  1144
#   current guess is: 2.856000000000126
#   f(guess) is: -5.971997640883501
#
# Iteration:  1145
#   current guess is: 2.855000000000126
#   f(guess) is: -5.979797219214788
#
# Iteration:  1146
#   current guess is: 2.854000000000126
#   f(guess) is: -5.987521607009853
#
# Iteration:  1147
#   current guess is: 2.8530000000001263
#   f(guess) is: -5.995170926079368
#
# Iteration:  1148
#   current guess is: 2.8520000000001264
#   f(guess) is: -6.00274529813089
#
# Iteration:  1149
#   current guess is: 2.8510000000001265
#   f(guess) is: -6.010244844769886
#
# Iteration:  1150
#   current guess is: 2.8500000000001267
#   f(guess) is: -6.0176696874989375
#
# Iteration:  1151
#   current guess is: 2.8490000000001268
#   f(guess) is: -6.025019947719784
#
# Iteration:  1152
#   current guess is: 2.848000000000127
#   f(guess) is: -6.032295746731279
#
# Iteration:  1153
#   current guess is: 2.847000000000127
#   f(guess) is: -6.039497205729958
#
# Iteration:  1154
#   current guess is: 2.846000000000127
#   f(guess) is: -6.046624445812199
#
# Iteration:  1155
#   current guess is: 2.845000000000127
#   f(guess) is: -6.053677587971038
#
# Iteration:  1156
#   current guess is: 2.8440000000001273
#   f(guess) is: -6.060656753099124
#
# Iteration:  1157
#   current guess is: 2.8430000000001274
#   f(guess) is: -6.067562061986791
#
# Iteration:  1158
#   current guess is: 2.8420000000001275
#   f(guess) is: -6.074393635323986
#
# Iteration:  1159
#   current guess is: 2.8410000000001276
#   f(guess) is: -6.081151593698905
#
# Iteration:  1160
#   current guess is: 2.8400000000001278
#   f(guess) is: -6.087836057599361
#
# Iteration:  1161
#   current guess is: 2.839000000000128
#   f(guess) is: -6.0944471474109605
#
# Iteration:  1162
#   current guess is: 2.838000000000128
#   f(guess) is: -6.100984983420403
#
# Iteration:  1163
#   current guess is: 2.837000000000128
#   f(guess) is: -6.1074496858111615
#
# Iteration:  1164
#   current guess is: 2.836000000000128
#   f(guess) is: -6.113841374668823
#
# Iteration:  1165
#   current guess is: 2.8350000000001283
#   f(guess) is: -6.1201601699775665
#
# Iteration:  1166
#   current guess is: 2.8340000000001284
#   f(guess) is: -6.126406191619594
#
# Iteration:  1167
#   current guess is: 2.8330000000001285
#   f(guess) is: -6.132579559379792
#
# Iteration:  1168
#   current guess is: 2.8320000000001286
#   f(guess) is: -6.138680392940842
#
# Iteration:  1169
#   current guess is: 2.8310000000001287
#   f(guess) is: -6.144708811885948
#
# Iteration:  1170
#   current guess is: 2.830000000000129
#   f(guess) is: -6.150664935699183
#
# Iteration:  1171
#   current guess is: 2.829000000000129
#   f(guess) is: -6.156548883764003
#
# Iteration:  1172
#   current guess is: 2.828000000000129
#   f(guess) is: -6.162360775364959
#
# Iteration:  1173
#   current guess is: 2.827000000000129
#   f(guess) is: -6.168100729686557
#
# Iteration:  1174
#   current guess is: 2.8260000000001293
#   f(guess) is: -6.173768865814054
#
# Iteration:  1175
#   current guess is: 2.8250000000001294
#   f(guess) is: -6.179365302733686
#
# Iteration:  1176
#   current guess is: 2.8240000000001295
#   f(guess) is: -6.18489015933244
#
# Iteration:  1177
#   current guess is: 2.8230000000001296
#   f(guess) is: -6.190343554398964
#
# Iteration:  1178
#   current guess is: 2.8220000000001297
#   f(guess) is: -6.195725606621636
#
# Iteration:  1179
#   current guess is: 2.82100000000013
#   f(guess) is: -6.20103643459106
#
# Iteration:  1180
#   current guess is: 2.82000000000013
#   f(guess) is: -6.20627615679939
#
# Iteration:  1181
#   current guess is: 2.81900000000013
#   f(guess) is: -6.211444891639189
#
# Iteration:  1182
#   current guess is: 2.81800000000013
#   f(guess) is: -6.2165427574058185
#
# Iteration:  1183
#   current guess is: 2.8170000000001303
#   f(guess) is: -6.221569872295618
#
# Iteration:  1184
#   current guess is: 2.8160000000001304
#   f(guess) is: -6.226526354406587
#
# Iteration:  1185
#   current guess is: 2.8150000000001305
#   f(guess) is: -6.231412321739867
#
# Iteration:  1186
#   current guess is: 2.8140000000001306
#   f(guess) is: -6.236227892197576
#
# Iteration:  1187
#   current guess is: 2.8130000000001307
#   f(guess) is: -6.240973183584288
#
# Iteration:  1188
#   current guess is: 2.812000000000131
#   f(guess) is: -6.2456483136063525
#
# Iteration:  1189
#   current guess is: 2.811000000000131
#   f(guess) is: -6.250253399874509
#
# Iteration:  1190
#   current guess is: 2.810000000000131
#   f(guess) is: -6.25478855989968
#
# Iteration:  1191
#   current guess is: 2.809000000000131
#   f(guess) is: -6.2592539110961525
#
# Iteration:  1192
#   current guess is: 2.8080000000001313
#   f(guess) is: -6.263649570782832
#
# Iteration:  1193
#   current guess is: 2.8070000000001314
#   f(guess) is: -6.267975656178578
#
# Iteration:  1194
#   current guess is: 2.8060000000001315
#   f(guess) is: -6.272232284407551
#
# Iteration:  1195
#   current guess is: 2.8050000000001316
#   f(guess) is: -6.276419572496593
#
# Iteration:  1196
#   current guess is: 2.8040000000001317
#   f(guess) is: -6.280537637374209
#
# Iteration:  1197
#   current guess is: 2.803000000000132
#   f(guess) is: -6.284586595875112
#
# Iteration:  1198
#   current guess is: 2.802000000000132
#   f(guess) is: -6.2885665647353335
#
# Iteration:  1199
#   current guess is: 2.801000000000132
#   f(guess) is: -6.292477660595523
#
# Iteration:  1200
#   current guess is: 2.800000000000132
#   f(guess) is: -6.296319999999355
#
# Iteration:  1201
#   current guess is: 2.7990000000001323
#   f(guess) is: -6.300093699395575
#
# Iteration:  1202
#   current guess is: 2.7980000000001324
#   f(guess) is: -6.303798875135612
#
# Iteration:  1203
#   current guess is: 2.7970000000001325
#   f(guess) is: -6.307435643475856
#
# Iteration:  1204
#   current guess is: 2.7960000000001326
#   f(guess) is: -6.3110041205766265
#
# Iteration:  1205
#   current guess is: 2.7950000000001327
#   f(guess) is: -6.314504422502523
#
# Iteration:  1206
#   current guess is: 2.794000000000133
#   f(guess) is: -6.317936665223442
#
# Iteration:  1207
#   current guess is: 2.793000000000133
#   f(guess) is: -6.321300964612419
#
# Iteration:  1208
#   current guess is: 2.792000000000133
#   f(guess) is: -6.324597436448357
#
# Iteration:  1209
#   current guess is: 2.791000000000133
#   f(guess) is: -6.327826196414549
#
# Iteration:  1210
#   current guess is: 2.7900000000001333
#   f(guess) is: -6.330987360099698
#
# Iteration:  1211
#   current guess is: 2.7890000000001334
#   f(guess) is: -6.334081042996559
#
# Iteration:  1212
#   current guess is: 2.7880000000001335
#   f(guess) is: -6.337107360504319
#
# Iteration:  1213
#   current guess is: 2.7870000000001336
#   f(guess) is: -6.3400664279268995
#
# Iteration:  1214
#   current guess is: 2.7860000000001337
#   f(guess) is: -6.3429583604734034
#
# Iteration:  1215
#   current guess is: 2.785000000000134
#   f(guess) is: -6.3457832732590305
#
# Iteration:  1216
#   current guess is: 2.784000000000134
#   f(guess) is: -6.348541281304165
#
# Iteration:  1217
#   current guess is: 2.783000000000134
#   f(guess) is: -6.351232499535399
#
# Iteration:  1218
#   current guess is: 2.782000000000134
#   f(guess) is: -6.353857042785307
#
# Iteration:  1219
#   current guess is: 2.7810000000001343
#   f(guess) is: -6.356415025791989
#
# Iteration:  1220
#   current guess is: 2.7800000000001344
#   f(guess) is: -6.358906563199753
#
# Iteration:  1221
#   current guess is: 2.7790000000001345
#   f(guess) is: -6.361331769559683
#
# Iteration:  1222
#   current guess is: 2.7780000000001346
#   f(guess) is: -6.363690759329302
#
# Iteration:  1223
#   current guess is: 2.7770000000001347
#   f(guess) is: -6.365983646871882
#
# Iteration:  1224
#   current guess is: 2.776000000000135
#   f(guess) is: -6.368210546458613
#
# Iteration:  1225
#   current guess is: 2.775000000000135
#   f(guess) is: -6.370371572265185
#
# Iteration:  1226
#   current guess is: 2.774000000000135
#   f(guess) is: -6.372466838377022
#
# Iteration:  1227
#   current guess is: 2.773000000000135
#   f(guess) is: -6.374496458784506
#
# Iteration:  1228
#   current guess is: 2.7720000000001352
#   f(guess) is: -6.376460547386159
#
# Iteration:  1229
#   current guess is: 2.7710000000001354
#   f(guess) is: -6.37835921798694
#
# Iteration:  1230
#   current guess is: 2.7700000000001355
#   f(guess) is: -6.380192584299721
#
# Iteration:  1231
#   current guess is: 2.7690000000001356
#   f(guess) is: -6.3819607599449455
#
# Iteration:  1232
#   current guess is: 2.7680000000001357
#   f(guess) is: -6.383663858450291
#
# Iteration:  1233
#   current guess is: 2.767000000000136
#   f(guess) is: -6.385301993251119
#
# Iteration:  1234
#   current guess is: 2.766000000000136
#   f(guess) is: -6.386875277691047
#
# Iteration:  1235
#   current guess is: 2.765000000000136
#   f(guess) is: -6.388383825021606
#
# Iteration:  1236
#   current guess is: 2.764000000000136
#   f(guess) is: -6.389827748401785
#
# Iteration:  1237
#   current guess is: 2.7630000000001362
#   f(guess) is: -6.391207160899739
#
# Iteration:  1238
#   current guess is: 2.7620000000001363
#   f(guess) is: -6.392522175490967
#
# Iteration:  1239
#   current guess is: 2.7610000000001365
#   f(guess) is: -6.393772905060018
#
# Iteration:  1240
#   current guess is: 2.7600000000001366
#   f(guess) is: -6.394959462399811
#
# Iteration:  1241
#   current guess is: 2.7590000000001367
#   f(guess) is: -6.396081960211745
#
# Iteration:  1242
#   current guess is: 2.758000000000137
#   f(guess) is: -6.397140511107295
#
# Iteration:  1243
#   current guess is: 2.757000000000137
#   f(guess) is: -6.3981352276044845
#
# Iteration:  1244
#   current guess is: 2.756000000000137
#   f(guess) is: -6.399066222131978
#
# Iteration:  1245
#   current guess is: 2.755000000000137
#   f(guess) is: -6.399933607028061
#
# Iteration:  1246
#   current guess is: 2.7540000000001372
#   f(guess) is: -6.400737494538703
#
# Iteration:  1247
#   current guess is: 2.7530000000001373
#   f(guess) is: -6.401477996820859
#
# Iteration:  1248
#   current guess is: 2.7520000000001374
#   f(guess) is: -6.402155225939737
#
# Iteration:  1249
#   current guess is: 2.7510000000001376
#   f(guess) is: -6.402769293871188
#
# Iteration:  1250
#   current guess is: 2.7500000000001377
#   f(guess) is: -6.403320312499886
#
# Iteration:  1251
#   current guess is: 2.7490000000001378
#   f(guess) is: -6.403808393621034
#
# Iteration:  1252
#   current guess is: 2.748000000000138
#   f(guess) is: -6.404233648940249
#
# Iteration:  1253
#   current guess is: 2.747000000000138
#   f(guess) is: -6.404596190071402
#
# Iteration:  1254
#   current guess is: 2.746000000000138
#   f(guess) is: -6.404896128540827
#
# Iteration:  1255
#   current guess is: 2.745000000000138
#   f(guess) is: -6.405133575784362
#
# Iteration:  1256
#   current guess is: 2.7440000000001383
#   f(guess) is: -6.405308643147578
#
# Iteration:  1257
#   current guess is: 2.7430000000001384
#   f(guess) is: -6.405421441888052
#
# Iteration:  1258
#   current guess is: 2.7420000000001385
#   f(guess) is: -6.405472083172754
#
# I set the initial guess to '4' and the step size to '0.001'.
# The minimum is -6.405472083172754 when the search stops at x = 2.7420000000001385.
# ========================================
#
#   由此可知我雖然找到小數點以下第三位答案，但iteration次數大大增加
#   從原本的iterate 1次變成iterate 1258次
#   這在函數值劇烈變動的函數上尤為明顯，例如func_5
